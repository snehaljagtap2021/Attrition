# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import the file

# %%
path = 'C:\\Users\\User\\Desktop\\DATA SCIENCE\\Abhinav R\\datasets\\Attrition Case Study.csv'
data = pd.read_csv(path)

# %%
data.columns
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #  Explore the data

# %%
data.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.dtypes
# Out:
# Attrition                    int64
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
len(data.index)
# Out:
# 1470

# %% [markdown]
# # Convert categorical predictors to type 'category'

# %%
data['OverTime'] = data['OverTime'].astype('category')
data['Over18'] = data['Over18'].astype('category')
data['MaritalStatus'] = data['MaritalStatus'].astype('category')
data['JobRole'] = data['JobRole'].astype('category')
data['Gender'] = data['Gender'].astype('category')
data['EducationField'] = data['EducationField'].astype('category')
data['Department'] = data['Department'].astype('category')
data['BusinessTravel'] = data['BusinessTravel'].astype('category')
data['Attrition'] = data['Attrition'].astype('category')
data['Education'] = data['Education'].astype('category')
data['EnvironmentSatisfaction'] = data['EnvironmentSatisfaction'].astype('category')
data['JobInvolvement'] = data['JobInvolvement'].astype('category')
data['JobLevel'] = data['JobLevel'].astype('category')
data['JobSatisfaction'] = data['JobSatisfaction'].astype('category')
data['PerformanceRating'] = data['PerformanceRating'].astype('category')
data['RelationshipSatisfaction'] = data['RelationshipSatisfaction'].astype('category')
data['StockOptionLevel'] = data['StockOptionLevel'].astype('category')
data['WorkLifeBalance'] = data['WorkLifeBalance'].astype('category')

# %%
data.dtypes
# Out:
# Attrition                   category
# Age                            int64
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                   category
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction     category
# Gender                      category
# HourlyRate                     int64
# JobInvolvement              category
# JobLevel                    category
# JobRole                     category
# JobSatisfaction             category
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                      category
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating           category
# ...

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        print("="*50)
        print(data_columns[i])
        print("="*50,'\n')
        
        
    
    else:
        print(data_columns[i])
        print("-"*50)
        print(data[data_columns[i]].value_counts())
        print("-"*50,'\n')
# Out:
# Attrition
# --------------------------------------------------
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# --------------------------------------------------
#
# ...
# Age
# ...
#
# BusinessTravel
# --------------------------------------------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# --------------------------------------------------
#
# ...
# DailyRate
# ...
#
# Department
# --------------------------------------------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# --------------------------------------------------
#
# ...
# DistanceFromHome
# ...
#
# Education
# --------------------------------------------------
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# --------------------------------------------------
#
# EducationField
# --------------------------------------------------
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Quantitative data
#  * Box plot
#  * Histogram
#  * Strip plot
#  * Violin Plot
#  * Distribution with Histogram

# %% [markdown]
#  Categorical
#
#  * Bar graph
#  * Count plot
#  * Pie chart

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        plt.figure(1)
        plt.figure(figsize=(12,8))
        plt.subplot(2,2,1)
        sns.boxplot(x=data[data_columns[i]],data = data)
        plt.subplot(2,2,2)
        plt.hist(data[data_columns[i]]);
        plt.xlabel(data_columns[i])
        plt.tight_layout()  #improves spacing
        plt.show()
        
        
    else:
        
        plt.figure()
        sns.countplot(x=data[data_columns[i]], data = data)

# %%
# Age
plt.figure()
sns.boxplot(data['Age'])

# %%
plt.figure()
plt.hist(data['Age']);
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
sns.distplot(data['Age'])
plt.show()

# %%
sns.stripplot(x='Age',data=data, jitter=True)
plt.xlabel("Age")
plt.show()

# %%
sns.violinplot(x='Age',data=data)
plt.xlabel("Age")
plt.show()

# %% [markdown]
# # Distribution of all quantitative predictors

# %%
fig,ax = plt.subplots(4,4, figsize=(18,18))              
sns.distplot(data['TotalWorkingYears'], ax = ax[0,0]) 
sns.distplot(data['YearsAtCompany'], ax = ax[0,1]) 
sns.distplot(data['DistanceFromHome'], ax = ax[0,2]) 
sns.distplot(data['NumCompaniesWorked'], ax = ax[0,3])
sns.distplot(data['YearsInCurrentRole'], ax = ax[1,0]) 
sns.distplot(data['YearsWithCurrManager'], ax = ax[1,1]) 
sns.distplot(data['YearsSinceLastPromotion'], ax = ax[1,2])
sns.distplot(data['HourlyRate'], ax = ax[1,3])
sns.distplot(data['PercentSalaryHike'], ax = ax[2,0]) 
sns.distplot(data['YearsSinceLastPromotion'], ax = ax[2,1]) 
sns.distplot(data['TrainingTimesLastYear'], ax = ax[2,2]) 
sns.distplot(data['MonthlyRate'], ax = ax[2,3])
sns.distplot(data['MonthlyIncome'], ax = ax[3,0])
sns.distplot(data['StandardHours'], ax = ax[3,1])
sns.distplot(data['Age'], ax = ax[3,2])
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# Quantitative --> Categorical
#
# * Horizontal Box plot

# %% [markdown]
# Categorical features
#
# * Contengency table
# * Count Plot with hue as target

# %%
data_columns = list()
data_columns = data.columns

for i in range(len(data_columns)):
    
    if data[data_columns[i]]. dtype == 'int64':
        
        plt.figure()
        sns.boxplot(x=data[data_columns[i]],y=data['Attrition'])
        
        
    else:
       
        plt.figure()
        sns.countplot(data=data,x= data_columns[i],hue="Attrition")

# %% [markdown]
# # Test of hypothesis

# %% [markdown]
#  Y=Attrition is categorical thus we do C --> C and Q --> C test of hypothesis
#
#  C --> C
#  Chi-square Test
#
#
#  Q --> C
#  Logistic Regression
#  Ho: Two variables are independent, Ha: Two variables are dependent
#  based on p-value

# %% [markdown]
# # C-->C  chi sq test

# %%
from statsmodels.stats.proportion import proportions_ztest

from scipy import stats
from scipy.stats import chi2

# %%
 #help(stats)
help(stats.chi2_contingency)
# Out:
# Help on function chi2_contingency in module scipy.stats.contingency:
#
# chi2_contingency(observed, correction=True, lambda_=None)
#     Chi-square test of independence of variables in a contingency table.
#
#     This function computes the chi-square statistic and p-value for the
#     hypothesis test of independence of the observed frequencies in the
#     contingency table [1]_ `observed`.  The expected frequencies are computed
#     based on the marginal sums under the assumption of independence; see
#     `scipy.stats.contingency.expected_freq`.  The number of degrees of
#     freedom is (expressed using numpy functions and attributes)::
#
#         dof = observed.size - sum(observed.shape) + observed.ndim - 1
#
#
#     Parameters
#     ----------
#     observed : array_like
#         The contingency table. The table contains the observed frequencies
#         (i.e. number of occurrences) in each category.  In the two-dimensional
# ...

# %%
ct_g = pd.crosstab(data['Gender'],data['Attrition'])
print(ct_g)
chi_out = stats.chi2_contingency(ct_g)
print(chi_out)
# Out:
# Attrition    0    1
# Gender
# Female     501   87
# Male       732  150
# (1.1169671241970975, 0.29057244902890855, 1, array([[493.2,  94.8],
#        [739.8, 142.2]]))

# %%
ct_bt = pd.crosstab(data['BusinessTravel'],data['Attrition'])
print(ct_bt)
chi_out = stats.chi2_contingency(ct_bt)
print(chi_out)
# Out:
# Attrition            0    1
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156
# (24.182413685655174, 5.608614476449931e-06, 2, array([[125.81632653,  24.18367347],
#        [232.34081633,  44.65918367],
#        [874.84285714, 168.15714286]]))

# %%
ct_dept = pd.crosstab(data['Department'],data['Attrition'])
print(ct_dept)
chi_out = stats.chi2_contingency(ct_dept)
print(chi_out)
# Out:
# Attrition                 0    1
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92
# (10.79600732241067, 0.004525606574479633, 2, array([[ 52.84285714,  10.15714286],
#        [806.06326531, 154.93673469],
#        [374.09387755,  71.90612245]]))

# %%
ct_edu = pd.crosstab(data['Education'],data['Attrition'])
print(ct_edu)
chi_out = stats.chi2_contingency(ct_edu)
print(chi_out)
# Out:
# Attrition    0   1
# Education
# 1          139  31
# 2          238  44
# 3          473  99
# 4          340  58
# 5           43   5
# (3.0739613982367193, 0.5455253376565949, 4, array([[142.59183673,  27.40816327],
#        [236.53469388,  45.46530612],
#        [479.77959184,  92.22040816],
#        [333.83265306,  64.16734694],
#        [ 40.26122449,   7.73877551]]))

# %%
ct_eduf = pd.crosstab(data['EducationField'],data['Attrition'])
print(ct_eduf)
chi_out = stats.chi2_contingency(ct_eduf)
print(chi_out)
# Out:
# Attrition           0   1
# EducationField
# Human Resources    20   7
# Life Sciences     517  89
# Marketing         124  35
# Medical           401  63
# Other              71  11
# Technical Degree  100  32
# (16.024674119585427, 0.006773980139025212, 5, array([[ 22.64693878,   4.35306122],
#        [508.29795918,  97.70204082],
#        [133.36530612,  25.63469388],
#        [389.19183673,  74.80816327],
#        [ 68.77959184,  13.22040816],
#        [110.71836735,  21.28163265]]))

# %%
ct_es = pd.crosstab(data['EnvironmentSatisfaction'],data['Attrition'])
print(ct_es)
chi_out = stats.chi2_contingency(ct_es)
print(chi_out)
# Out:
# Attrition                  0   1
# EnvironmentSatisfaction
# 1                        212  72
# 2                        244  43
# 3                        391  62
# 4                        386  60
# (22.503881435842295, 5.1234689062894205e-05, 3, array([[238.2122449 ,  45.7877551 ],
#        [240.72857143,  46.27142857],
#        [379.96530612,  73.03469388],
#        [374.09387755,  71.90612245]]))

# %%
ct_je = pd.crosstab(data['JobInvolvement'],data['Attrition'])
print(ct_je)
chi_out = stats.chi2_contingency(ct_je)
print(chi_out)
# Out:
# Attrition         0    1
# JobInvolvement
# 1                55   28
# 2               304   71
# 3               743  125
# 4               131   13
# (28.492021234659283, 2.8631806367134195e-06, 3, array([[ 69.61836735,  13.38163265],
#        [314.54081633,  60.45918367],
#        [728.05714286, 139.94285714],
#        [120.78367347,  23.21632653]]))

# %%
ct_jl = pd.crosstab(data['JobLevel'],data['Attrition'])
print(ct_jl)
chi_out = stats.chi2_contingency(ct_jl)
print(chi_out)
# Out:
# Attrition    0    1
# JobLevel
# 1          400  143
# 2          482   52
# 3          186   32
# 4          101    5
# 5           64    5
# (72.5290131066739, 6.634684715458957e-15, 4, array([[455.45510204,  87.54489796],
#        [447.90612245,  86.09387755],
#        [182.85306122,  35.14693878],
#        [ 88.91020408,  17.08979592],
#        [ 57.8755102 ,  11.1244898 ]]))

# %%
ct_jr = pd.crosstab(data['JobRole'],data['Attrition'])
print(ct_jr)
chi_out = stats.chi2_contingency(ct_jr)
print(chi_out)
# Out:
# Attrition                    0   1
# JobRole
# Healthcare Representative  122   9
# Human Resources             40  12
# Laboratory Technician      197  62
# Manager                     97   5
# Manufacturing Director     135  10
# Research Director           78   2
# Research Scientist         245  47
# Sales Executive            269  57
# Sales Representative        50  33
# (86.19025367670434, 2.752481638050657e-15, 8, array([[109.87959184,  21.12040816],
#        [ 43.61632653,   8.38367347],
#        [217.24285714,  41.75714286],
#        [ 85.55510204,  16.44489796],
#        [121.62244898,  23.37755102],
#        [ 67.10204082,  12.89795918],
#        [244.92244898,  47.07755102],
#        [273.44081633,  52.55918367],
#        [ 69.61836735,  13.38163265]]))

# %%
ct_js = pd.crosstab(data['JobSatisfaction'],data['Attrition'])
print(ct_js)
chi_out = stats.chi2_contingency(ct_js)
print(chi_out)
# Out:
# Attrition          0   1
# JobSatisfaction
# 1                223  66
# 2                234  46
# 3                369  73
# 4                407  52
# (17.505077010348, 0.0005563004510387556, 3, array([[242.40612245,  46.59387755],
#        [234.85714286,  45.14285714],
#        [370.73877551,  71.26122449],
#        [384.99795918,  74.00204082]]))

# %%
ct_marst = pd.crosstab(data['MaritalStatus'],data['Attrition'])
print(ct_marst)
chi_out = stats.chi2_contingency(ct_marst)
print(chi_out)
# Out:
# Attrition        0    1
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120
# (46.163676540848705, 9.45551106034083e-11, 2, array([[274.27959184,  52.72040816],
#        [564.49591837, 108.50408163],
#        [394.2244898 ,  75.7755102 ]]))

# %%
ct_o18 = pd.crosstab(data['Over18'],data['Attrition'])
print(ct_o18)
chi_out = stats.chi2_contingency(ct_o18)
print(chi_out)
# Out:
# Attrition     0    1
# Over18
# Y          1233  237
# (0.0, 1.0, 0, array([[1233.,  237.]]))

# %%
ct_ot = pd.crosstab(data['OverTime'],data['Attrition'])
print(ct_ot)
chi_out = stats.chi2_contingency(ct_ot)
print(chi_out)
# Out:
# Attrition    0    1
# OverTime
# No         944  110
# Yes        289  127
# (87.56429365828768, 8.15842372153832e-21, 1, array([[884.06938776, 169.93061224],
#        [348.93061224,  67.06938776]]))

# %%
ct_pr = pd.crosstab(data['PerformanceRating'],data['Attrition'])
print(ct_pr)
chi_out = stats.chi2_contingency(ct_pr)
print(chi_out)
# Out:
# Attrition             0    1
# PerformanceRating
# 3                  1044  200
# 4                   189   37
# (0.00015475439428271534, 0.9900745465934576, 1, array([[1043.43673469,  200.56326531],
#        [ 189.56326531,   36.43673469]]))

# %%
ct_rs = pd.crosstab(data['RelationshipSatisfaction'],data['Attrition'])
print(ct_rs)
chi_out = stats.chi2_contingency(ct_rs)
print(chi_out)
# Out:
# Attrition                   0   1
# RelationshipSatisfaction
# 1                         219  57
# 2                         258  45
# 3                         388  71
# 4                         368  64
# (5.241067859713709, 0.15497244371052638, 3, array([[231.50204082,  44.49795918],
#        [254.14897959,  48.85102041],
#        [384.99795918,  74.00204082],
#        [362.35102041,  69.64897959]]))

# %%
ct_sol = pd.crosstab(data['StockOptionLevel'],data['Attrition'])
print(ct_sol)
chi_out = stats.chi2_contingency(ct_sol)
print(chi_out)
# Out:
# Attrition           0    1
# StockOptionLevel
# 0                 477  154
# 1                 540   56
# 2                 146   12
# 3                  70   15
# (60.59830108612225, 4.379390336108354e-13, 3, array([[529.26734694, 101.73265306],
#        [499.91020408,  96.08979592],
#        [132.52653061,  25.47346939],
#        [ 71.29591837,  13.70408163]]))

# %%
ct_wlb = pd.crosstab(data['WorkLifeBalance'],data['Attrition'])
print(ct_wlb)
chi_out = stats.chi2_contingency(ct_wlb)
print(chi_out)
# Out:
# Attrition          0    1
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27
# (16.3250970916474, 0.0009725698845348824, 3, array([[ 67.10204082,  12.89795918],
#        [288.53877551,  55.46122449],
#        [749.02653061, 143.97346939],
#        [128.33265306,  24.66734694]]))

# %% [markdown]
# # Q-->C  Logistic Regression

# %%
import statsmodels.api as sm

# %%
help(sm.Logit)
# Out:
# Help on class Logit in module statsmodels.discrete.discrete_model:
#
# class Logit(BinaryModel)
#  |  Logit(endog, exog, **kwargs)
#  |
#  |  Binary choice logit model
#  |
#  |
#  |  Parameters
#  |  ----------
#  |  endog : array-like
#  |      1-d endogenous response variable. The dependent variable.
#  |  exog : array-like
#  |      A nobs x k array where `nobs` is the number of observations and `k`
#  |      is the number of regressors. An intercept is not included by default
#  |      and should be added by the user. See
#  |      :func:`statsmodels.tools.add_constant`.
#  |  missing : str
#  |      Available options are 'none', 'drop', and 'raise'. If 'none', no nan
#  |      checking is done. If 'drop', any observations with nans are dropped.
#  |      If 'raise', an error is raised. Default is 'none.'
#  |
#  |  Attributes
#  |  -----------
#  |  endog : array
#  |      A reference to the endogenous response variable
#  |  exog : array
# ...

# %%
import statsmodels.iolib
help(statsmodels.iolib.summary)
# Out:
# Help on module statsmodels.iolib.summary in statsmodels.iolib:
#
# NAME
#     statsmodels.iolib.summary
#
# CLASSES
#     builtins.object
#         Summary
#
#     class Summary(builtins.object)
#      |  class to hold tables for result summary presentation
#      |
#      |  Construction does not take any parameters. Tables and text can be added
#      |  with the `add_` methods.
#      |
#      |  Attributes
#      |  ----------
#      |  tables : list of tables
#      |      Contains the list of SimpleTable instances, horizontally concatenated tables are not saved separately.
#      |  extra_txt : string
#      |      extra lines that are added to the text output, used for warnings and explanations.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__(self)
#      |      Return str(self).
# ...

# %%
X = data['Age']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.428257
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.03042
# Time:                        22:39:47   Log-Likelihood:                -629.54
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 3.267e-10
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2062      0.306      0.674      0.500      -0.394       0.806
# ...

# %%
X = data['DailyRate']
y = data['Attrition']

X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.440087
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                0.003640
# Time:                        22:39:47   Log-Likelihood:                -646.93
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                   0.02969
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.3495      0.152     -8.872      0.000      -1.648      -1.051
# ...

# %%
X = data['DistanceFromHome']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.438776
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                0.006607
# Time:                        22:39:48   Log-Likelihood:                -645.00
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                  0.003399
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -1.8901      0.111    -16.969      0.000      -2.108      -1.672
# ...

# %%
X = data['HourlyRate']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441671
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:               5.304e-05
# Time:                        22:39:48   Log-Likelihood:                -649.26
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                    0.7930
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5889      0.240     -6.627      0.000      -2.059      -1.119
# ...

# %%
X = data['MonthlyRate']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441580
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:               0.0002605
# Time:                        22:39:49   Log-Likelihood:                -649.12
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                    0.5608
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -1.7327      0.161    -10.753      0.000      -2.049      -1.417
# ...

# %%
X = data['NumCompaniesWorked']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.440773
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                0.002088
# Time:                        22:39:50   Log-Likelihood:                -647.94
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                   0.09963
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -1.7765      0.106    -16.703      0.000      -1.985      -1.568
# ...

# %%
X = data['PercentSalaryHike']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441603
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:               0.0002071
# Time:                        22:39:50   Log-Likelihood:                -649.16
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                    0.6041
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.4956      0.305     -4.910      0.000      -2.093      -0.899
# ...

# %%
X = data['TotalWorkingYears']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.424516
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.03889
# Time:                        22:39:51   Log-Likelihood:                -624.04
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 1.187e-12
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.8831      0.127     -6.929      0.000      -1.133      -0.633
# ...

# %%
X = data['TrainingTimesLastYear']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.439886
#          Iterations 6
# ...
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                0.004096
# Time:                        22:39:51   Log-Likelihood:                -646.63
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                   0.02110
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
X = data['StandardHours']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441695
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1469
# Method:                           MLE   Df Model:                            0
# Date:                Sun, 03 May 2020   Pseudo R-squ.:               6.347e-11
# Time:                        22:39:52   Log-Likelihood:                -649.29
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                       nan
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# StandardHours    -0.0206      0.001    -23.252      0.000      -0.022      -0.019
# ...

# %%
X = data['YearsAtCompany']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.430782
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.02471
# Time:                        22:39:53   Log-Likelihood:                -633.25
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 1.477e-08
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -1.1558      0.111    -10.378      0.000      -1.374      -0.937
# ...

# %%
X = data['YearsInCurrentRole']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.427171
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.03288
# Time:                        22:39:53   Log-Likelihood:                -627.94
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 6.382e-11
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -1.1184      0.104    -10.775      0.000      -1.322      -0.915
# ...

# %%
X = data['YearsSinceLastPromotion']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441126
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                0.001289
# Time:                        22:39:54   Log-Likelihood:                -648.45
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                    0.1958
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
X = data['YearsWithCurrManager']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.428135
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.03070
# Time:                        22:39:54   Log-Likelihood:                -629.36
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 2.719e-10
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
X = data['MonthlyIncome']

y = data['Attrition']


X2 = sm.add_constant(X)
logit_model=sm.Logit(y,X2)
result=logit_model.fit()
#print(result)
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.426223
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1468
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 May 2020   Pseudo R-squ.:                 0.03503
# Time:                        22:39:55   Log-Likelihood:                -626.55
# converged:                       True   LL-Null:                       -649.29
#                                         LLR p-value:                 1.537e-11
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.9291      0.129     -7.191      0.000      -1.182      -0.676
# ...

# %% [markdown]
# # List of features selected by Test of Hypothesis

# %% [markdown]
# Attrition
# Age
# BusinessTravel
# DailyRate
# Department
# DistanceFromHome
# EducationField
# EnvironmentSatisfaction
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# MonthlyIncome
# NumCompaniesWorked
# OverTime
# RelationshipSatisfaction
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsWithCurrManager

# %% [markdown]
# # Drop unwanted features

# %%
toh_data = data.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18','MonthlyRate','HourlyRate',
                      'Education', 'Gender', 'PercentSalaryHike', 'PerformanceRating','YearsSinceLastPromotion'],axis=1)

# %%
len(toh_data.columns)
# Out:
# 24

# %%
toh_data.dtypes
# Out:
# Attrition                   category
# Age                            int64
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# EducationField              category
# EnvironmentSatisfaction     category
# JobInvolvement              category
# JobLevel                    category
# JobRole                     category
# JobSatisfaction             category
# MaritalStatus               category
# MonthlyIncome                  int64
# NumCompaniesWorked             int64
# OverTime                    category
# RelationshipSatisfaction    category
# StockOptionLevel            category
# TotalWorkingYears              int64
# TrainingTimesLastYear          int64
# WorkLifeBalance             category
# YearsAtCompany                 int64
# YearsInCurrentRole             int64
# YearsWithCurrManager           int64
# dtype: object

# %%
toh_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome  MonthlyIncome  \
# count  1470.000000  1470.000000       1470.000000    1470.000000
# mean     36.923810   802.485714          9.192517    6502.931293
# std       9.135373   403.509100          8.106864    4707.956783
# min      18.000000   102.000000          1.000000    1009.000000
# 25%      30.000000   465.000000          2.000000    2911.000000
# 50%      36.000000   802.000000          7.000000    4919.000000
# 75%      43.000000  1157.000000         14.000000    8379.000000
# max      60.000000  1499.000000         29.000000   19999.000000
#
#        NumCompaniesWorked  TotalWorkingYears  TrainingTimesLastYear  \
# count         1470.000000        1470.000000            1470.000000
# mean             2.693197          11.279592               2.799320
# std              2.498009           7.780782               1.289271
# min              0.000000           0.000000               0.000000
# ...

# %% [markdown]
# # Check and remove outliers

# %%
plt.figure()
sns.boxplot(toh_data['DailyRate'])

# %%
plt.figure()
sns.boxplot(toh_data['Age'])

# %%
plt.figure()
sns.boxplot(toh_data['DistanceFromHome'])

# %%
plt.figure()
sns.boxplot(toh_data['NumCompaniesWorked'])

# %%
plt.figure()
sns.boxplot(toh_data['TrainingTimesLastYear'])

# %%
plt.figure()
sns.boxplot(toh_data['TotalWorkingYears'])

# %%
# remove outliers

rws_TWY=toh_data.loc[toh_data.TotalWorkingYears>toh_data.TotalWorkingYears.quantile(.96)]
toh_data.drop(rws_TWY.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_TWY.index)
# Out:
# 53

# %%
plt.figure()
sns.boxplot(toh_data['TotalWorkingYears'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsAtCompany'])

# %%
# remove outliers

rws_yac=toh_data.loc[toh_data.YearsAtCompany>toh_data.YearsAtCompany.quantile(.96)]
toh_data.drop(rws_yac.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_yac.index)
# Out:
# 45

# %%
plt.figure()
sns.boxplot(toh_data['YearsAtCompany'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsInCurrentRole'])

# %%
# remove outliers

rws_yic=toh_data.loc[toh_data.YearsInCurrentRole>toh_data.YearsInCurrentRole.quantile(.98)]
toh_data.drop(rws_yic.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_yic.index)
# Out:
# 18

# %%
sns.boxplot(toh_data['YearsInCurrentRole'])

# %%
plt.figure()
sns.boxplot(toh_data['YearsWithCurrManager'])

# %%
# remove outliers

rws_ycm=toh_data.loc[toh_data.YearsWithCurrManager>toh_data.YearsWithCurrManager.quantile(.99)]
toh_data.drop(rws_ycm.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_ycm.index)
# Out:
# 9

# %%
plt.figure()
sns.boxplot(toh_data['YearsWithCurrManager'])

# %%
plt.figure()
sns.boxplot(toh_data['MonthlyIncome'])

# %%
# remove outliers

rws_mi=toh_data.loc[toh_data.MonthlyIncome>toh_data.MonthlyIncome.quantile(.92)]
toh_data.drop(rws_mi.index,inplace=True)
#print(rws_TWY.TotalWorkingYears)
len(rws_mi.index)
# Out:
# 108

# %%
plt.figure()
sns.boxplot(toh_data['MonthlyIncome'])

# %%
toh_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome  MonthlyIncome  \
# count  1237.000000  1237.000000       1237.000000    1237.000000
# mean     35.168149   805.202102          9.232821    4852.495554
# std       8.397441   402.482949          8.033755    2492.853421
# min      18.000000   103.000000          1.000000    1009.000000
# 25%      29.000000   469.000000          2.000000    2741.000000
# 50%      34.000000   804.000000          7.000000    4377.000000
# 75%      40.000000  1157.000000         14.000000    6230.000000
# max      60.000000  1499.000000         29.000000   11916.000000
#
#        NumCompaniesWorked  TotalWorkingYears  TrainingTimesLastYear  \
# count         1237.000000        1237.000000            1237.000000
# mean             2.575586           8.829426               2.818917
# std              2.469913           5.095766               1.312572
# min              0.000000           0.000000               0.000000
# ...

# %%
# Create dummy varables for categorical features

TOH_DATA = pd.get_dummies(toh_data ,columns = ['Department','EducationField','BusinessTravel','JobRole','OverTime','MaritalStatus']
                     ,drop_first=True)

# %%
TOH_DATA.columns
# Out:
# Index(['Attrition', 'Age', 'DailyRate', 'DistanceFromHome',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsWithCurrManager',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'BusinessTravel_Travel_Frequently',
#        'BusinessTravel_Travel_Rarely', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Manufacturing Director', 'JobRole_Research Director',
#        'JobRole_Research Scientist', 'JobRole_Sales Executive',
# ...

# %%
len(TOH_DATA)
# Out:
# 1237

# %%
path_toh= "C:\\Users\\User\\Desktop\\DATA SCIENCE\\Abhinav R\\datasets\\Attrition_EDA_TOH.csv"
TOH_DATA.to_csv(path_toh)

# %% [markdown]
# # By performing Exploratory Data Analysis and Test of hypothesis, the final required data is stored in a file 'Attrition_EDA_TOH.csv'.
